# %% [markdown]
# # Earthquake Damage Assessment
#
# In this notebook, we will perform an **earthquake damage and risk assessment** for transportation infrastructure, specifically focusing on roads. The assessment is based on combining hazard data (e.g., PGA levels) with vulnerability curves to estimate the potential damage to infrastructure.
#
# We will follow the steps outlined below to conduct the assessment:
#
# 1. **Loading the necessary packages:**
#    We will import the Python libraries required for data handling, analysis, and visualization.
#
# 2. **Loading the data:**
#    The infrastructure data (e.g., roads) and hazard data (e.g., PGA levels) will be loaded into the notebook.
#
# 3. **Preparing the data:**
#    The infrastructure and hazard data will be processed and data gaps can be filled, if required.
#
# 4. **Performing the damage assessment:**
#    We will apply vulnerability curves to estimate the potential damage based on the intensity of the hazard.
#
# 5. **Visualizing the results:**
#    Finally, we will visualize the estimated damage using graphs and maps to illustrate the impact on transportation infrastructure.

# %% [markdown]
# ## 1. Loading the Necessary Packages
# To perform the assessment, we are going to make use of several [python packages](https://docs.python.org/3/tutorial/modules.html#packages).
#
# In case you run this in Google Colab, you will have to install the packages below **(remove the hashtag in front of them)**.

# %%
#!pip install damagescanner==0.9b14
#!pip install contextily
#!pip install exactextract
#!pip install lonboard

# %% [markdown]
# In this step, we will import all the required Python libraries for data manipulation, spatial analysis, and visualization.

# %%
import warnings
import xarray as xr
import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns
import shapely
from tqdm import tqdm

import matplotlib.pyplot as plt
import contextily as cx
import rasterio
from rasterio.plot import show

import damagescanner.download as download
from damagescanner.core import DamageScanner
from damagescanner.osm import read_osm_data
from damagescanner.base_values import DICT_CIS_VULNERABILITY_FLOOD
from statistics import mode

from lonboard import viz

warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning) # exactextract gives a warning that is invalid

# %% [markdown]
# ### Specify the country of interest

# %% [markdown]
# Before we continue, we should specify the country for which we want to assess the damage. We use the ISO3 code for the country to download the OpenStreetMap data.

# %%
country_full_name = 'Angola'
country_iso3 = 'AGO'

# %% [markdown]
# ## 2. Loading the Data
# In this step, we will load four key datasets:
#
# 1. **Infrastructure data:**
#    This dataset contains information on the location and type of transportation infrastructure (e.g., roads). Each asset may have attributes such as type, length, and replacement cost.
#
# 2. **Hazard data:**
#    This dataset includes information on the hazard affecting the infrastructure (e.g., flood depth at various locations).
#
# 3. **Vulnerability curves:**
#    Vulnerability curves define how the infrastructure's damage increases with the intensity of the hazard. For example, flood depth-damage curves specify how much damage occurs for different flood depths.
#
# 4. **Maximum damage values:**
#    This dataset contains the maximum possible damage (in monetary terms) that can be incurred by individual infrastructure assets. This is crucial for calculating total damage based on the vulnerability curves.

# %% [markdown]
# ### Infrastructure Data
#
# We will perform this example analysis for Tajikistan. To start the analysis, we first download the OpenStreetMap data from GeoFabrik. In case of locally available data, one can load the shapefiles through **gpd.read_file()**, as we show in the second cell within this section.

# %%
infrastructure_path = download.get_country_geofabrik(country_iso3)

# %%
city_path = gpd.read_file('/Users/ipshitakarmakar/Dropbox (Personal)/WB/Angola/AOI/Huambo.shp')
city_path.set_crs(epsg=4326, inplace=True)
# Out:
#   GID_0 COUNTRY    GID_1  NAME_1 NL_NAME_1      GID_2  NAME_2 NL_NAME_2  \
# 0   AGO  Angola  AGO.9_1  Huambo        NA  AGO.9.5_1  Huambo        NA
#
#          GID_3   NAME_3 VARNAME_3 NL_NAME_3   TYPE_3 ENGTYPE_3 CC_3 HASC_3  \
# 0  AGO.9.5.1_1  Chipipa        NA        NA  Commune   Commune   NA     NA
#
#                                             geometry
# 0  POLYGON ((15.8424 -12.55896, 15.84247 -12.5590...

# %% [markdown]
# Now we load the data and read only the road data.

# %%
# %%time
features = read_osm_data(infrastructure_path,asset_type='roads')
# Out:
# CPU times: user 9.55 s, sys: 1.07 s, total: 10.6 s
# Wall time: 10.3 s

# %%
features= gpd.read_file('/Users/ipshitakarmakar/Documents/infrastructure/mnt/city-directories/Infrastructure/Shapefiles/huambo_revised/Lines/Existing/15kv/huambo_15kv_existing_underground.shp')

# %%
clipped_features = gpd.clip(features, city_path)
clipped_features["object_type"] = "Cable"

# %%
fig, ax = plt.subplots(figsize=(10, 10))
clipped_features.plot(ax=ax, edgecolor='red', facecolor='none')
city_path.plot(ax=ax, edgecolor='blue', facecolor='none', lw=2, linestyle='--')
ax.set_title('City Infra')
plt.show()

# %%
sub_types = clipped_features.object_type.unique()

# %%
sub_types
# Out:
# array(['Cable'], dtype=object)

# %% [markdown]
# ### Hazard Data
# For this example, we make use of the flood data provided by [CDRI](https://giri.unepgrid.ch/map?list=explore).
#
# We use a 1/475 earthquake hazard map to showcase the approach.

# %%
hazard_map = xr.open_dataset("https://hazards-data.unepgrid.ch/PGA_475y.tif", engine="rasterio")

# %% [markdown]
# ### Maximum damages
# One of the most difficult parts of the assessment is to define the maximum reconstruction cost of particular assets. Here we provide a baseline set of values, but these should be updated through national consultations.

# %%
maxdam_dict = {'Cable':300, 
              }

# %% [markdown]
# To be used in our damage assessment, we convert this to a Pandas DataFrame

# %%
maxdam = pd.DataFrame.from_dict(maxdam_dict,orient='index').reset_index()
maxdam.columns = ['object_type','damage']

# %% [markdown]
# And check if any of the objects are missing from the dataframe.

# %%
missing = set(sub_types) - set(maxdam.object_type)

if len(missing) > 0:
    print(f"Missing object types in maxdam: \033[1m{', '.join(missing)}\033[0m. Please add them before you continue.")

# %% [markdown]
# ### Vulnerability data
# Similarly to the maximum damages, specifying the vulnerability curves is complex. We generally have limited information about the quality of the assets, its level of deteriation and other asset-level characteristics. The study by Nirandjan et al. (2024) provides us with a baseline set of fragility and vulnerability curves that one can use. In the following cell, we load that data.

# %%
vulnerability_path = "https://zenodo.org/records/13889558/files/Table_D2_Hazard_Fragility_and_Vulnerability_Curves_V1.1.0.xlsx?download=1"
vul_df = pd.read_excel(vulnerability_path,sheet_name='E_Vuln_PGA ')

# %% [markdown]
# And let's have a look at all the available options

# %%
with pd.option_context('display.max_rows', None, 'display.max_colwidth', None):
  display(vul_df.iloc[:2,:].T)
# Out:
#                                                  0  \
# ID number                      Infrastructure type
# E1.1                                   Power plant
# E1.1a                                  Power plant
# E1.1b                                  Power plant
# E1.2                                   Power plant
# E1.2a                                  Power plant
# E1.2b                                  Power plant
# E1.3                                   Power plant
# E1.3a                                  Power plant
# E1.3b                                  Power plant
# E1.4                                   Power plant
# E1.4a                                  Power plant
# E1.4b                                  Power plant
# E1.15                            Hydropower plants
# E2.1                                    substation
# E2.1a                                   substation
# E2.1b                                   substation
# E2.2                                    substation
# E2.2a                                   substation
# E2.2b                                   substation
# E2.3                                    substation
# E2.3a                                   substation
# E2.3b                                   substation
# E2.4                                    substation
# E2.4a                                   substation
# E2.4b                                   substation
# E2.5                                    substation
# E2.5a                                   substation
# E2.5b                                   substation
# E2.6                                    substation
# E2.6a                                   substation
# E2.6b                                   substation
# E2.9a                                   Substation
# E2.9b                                   Substation
# E4.1                                    Power pole
# E4.1a                                   Power pole
# E4.1b                                   Power pole
# E4.2                                    Power pole
# E4.2a                                   Power pole
# E4.2b                                   Power pole
# E5.1                                         Cable
# E5.1a                                        Cable
# E5.1b                                        Cable
# E5.2                                         Cable
# E5.2a                                        Cable
# E5.2b                                        Cable
# E6.1                                   Power lines
# E6.1a                                  Power lines
# E6.1b                                  Power lines
# E6.2                                   Power lines
# E6.2a                                  Power lines
# E6.2b                                  Power lines
# E8.1                                       Railway
# E8.1a                                      Railway
# E8.1b                                      Railway
# E8.2                                       Railway
# E8.2a                                      Railway
# E8.2b                                      Railway
# E8.3                                       Railway
# E8.3a                                      Railway
# E8.3b                                      Railway
# E8.4                                       Railway
# E8.4a                                      Railway
# E8.4b                                      Railway
# E8.5                                       Railway
# E8.5a                                      Railway
# E8.5b                                      Railway
# E8.6                                       Railway
# E8.6a                                      Railway
# E8.6b                                      Railway
# E8.7                                       Railway
# E8.7a                                      Railway
# E8.7b                                      Railway
# E8.8                                       Railway
# E8.8a                                      Railway
# E8.8b                                      Railway
# E8.9                                       Railway
# E8.9a                                      Railway
# E8.9b                                      Railway
# E8.10                                      Railway
# E8.10a                                     Railway
# E8.10b                                     Railway
# E9.1                                      Airports
# E9.1a                                     Airports
# E9.1b                                     Airports
# E9.2                                      Airports
# E9.2a                                     Airports
# E9.2b                                     Airports
# E9.3                                      Airports
# E9.3a                                     Airports
# E9.3b                                     Airports
# E9.4                                      Airports
# E9.4a                                     Airports
# E9.4b                                     Airports
# E12.1                                       Others
# E12.1a                                      Others
# E12.1b                                      Others
# E12.2                                       Others
# E12.2a                                      Others
# E12.2b                                      Others
# E13.1                            Reservoir covered
# E13.1a                           Reservoir covered
# E13.1b                           Reservoir covered
# E13.2                            Reservoir covered
# E13.2a                           Reservoir covered
# E13.2b                           Reservoir covered
# E13.3                            Reservoir covered
# E13.3a                           Reservoir covered
# E13.3b                           Reservoir covered
# E13.4                            Reservoir covered
# E13.4a                           Reservoir covered
# E13.4b                           Reservoir covered
# E13.5                            Reservoir covered
# E13.5a                           Reservoir covered
# E13.5b                           Reservoir covered
# E13.6                            Reservoir covered
# E13.6a                           Reservoir covered
# E13.6b                           Reservoir covered
# E14.1                        Water treatment plant
# E14.1 a                      Water treatment plant
# E14.1b                       Water treatment plant
# E14.2                        Water treatment plant
# E14.2a                       Water treatment plant
# E14.2b                       Water treatment plant
# E14.3                        Water treatment plant
# E14.3a                       Water treatment plant
# E14.3b                       Water treatment plant
# E14.4                        Water treatment plant
# E14.4a                       Water treatment plant
# E14.4b                       Water treatment plant
# E14.5                        Water treatment plant
# E14.5a                       Water treatment plant
# E14.5b                       Water treatment plant
# E14.6                        Water treatment plant
# E14.6a                       Water treatment plant
# E14.6b                       Water treatment plant
# E15.1                                   Water well
# E15.1a                                  Water well
# E15.1b                                  Water well
# E16.24     Transmission and distribution pipelines
# E17.1                                       Others
# E17.1a                                      Others
# E17.1b                                      Others
# E17.2                                       Others
# E17.2a                                      Others
# E17.2b                                      Others
# E17.3                                       Others
# E17.3a                                      Others
# E17.3b                                      Others
# E17.4                                       Others
# E17.4a                                      Others
# E17.4b                                      Others
# E18.1                   Wastewater treatment plant
# E18.1a                  Wastewater treatment plant
# E18.1b                  Wastewater treatment plant
# E18.2                   Wastewater treatment plant
# E18.2a                  Wastewater treatment plant
# E18.2b                  Wastewater treatment plant
# E18.3                   Wastewater treatment plant
# E18.3a                  Wastewater treatment plant
# E18.3b                  Wastewater treatment plant
# E18.4                   Wastewater treatment plant
# E18.4a                  Wastewater treatment plant
# E18.4b                  Wastewater treatment plant
# E18.5                   Wastewater treatment plant
# E18.5a                  Wastewater treatment plant
# E18.5b                  Wastewater treatment plant
# E18.6                   Wastewater treatment plant
# E18.6a                  Wastewater treatment plant
# E18.6b                  Wastewater treatment plant
# E20.1                                       Others
# E20.1a                                      Others
# E20.1b                                      Others
# E20.2                                       Others
# E20.2a                                      Others
# E20.2b                                      Others
# E20.3                                       Others
# E20.3a                                      Others
# E20.3b                                      Others
# E20.4                                       Others
# E20.4a                                      Others
# E20.4b                                      Others
# E21.11                      Educational facilities
# E21.11a                     Educational facilities
# E21.11b                     Educational facilities
#
#                                                                                                                                                          1
# ID number                                                                                                                      Infrastructure type details
# E1.1                                                                                                  Small generation facilities with anchored components
# E1.1a                                                                                                 Small generation facilities with anchored components
# E1.1b                                                                                                 Small generation facilities with anchored components
# E1.2                                                                                                Small generation facilities with unanchored components
# E1.2a                                                                                               Small generation facilities with unanchored components
# E1.2b                                                                                               Small generation facilities with unanchored components
# E1.3                                                                                                           Medium/large power with anchored components
# E1.3a                                                                                                          Medium/large power with anchored components
# E1.3b                                                                                                          Medium/large power with anchored components
# E1.4                                                                                                         Medium/large power with unanchored components
# E1.4a                                                                                                        Medium/large power with unanchored components
# E1.4b                                                                                                        Medium/large power with unanchored components
# E1.15                                                                                                                                                  NaN
# E2.1                                                                                                                       Low Voltage Substation anchored
# E2.1a                                                                                                                      Low Voltage Substation anchored
# E2.1b                                                                                                                      Low Voltage Substation anchored
# E2.2                                                                                                                     Low Voltage Substation unanchored
# E2.2a                                                                                                                    Low Voltage Substation unanchored
# E2.2b                                                                                                                    Low Voltage Substation unanchored
# E2.3                                                                                                                    Medium Voltage Substation anchored
# E2.3a                                                                                                                   Medium Voltage Substation anchored
# E2.3b                                                                                                                   Medium Voltage Substation anchored
# E2.4                                                                                                                  Medium Voltage Substation unanchored
# E2.4a                                                                                                                 Medium Voltage Substation unanchored
# E2.4b                                                                                                                 Medium Voltage Substation unanchored
# E2.5                                                                                                                      High Voltage Substation anchored
# E2.5a                                                                                                                     High Voltage Substation anchored
# E2.5b                                                                                                                     High Voltage Substation anchored
# E2.6                                                                                                                    High Voltage Substation unanchored
# E2.6a                                                                                                                   High Voltage Substation unanchored
# E2.6b                                                                                                                   High Voltage Substation unanchored
# E2.9a                                                                                                                    Low Voltage Substation unanchored
# E2.9b                                                                                                                    Low Voltage Substation unanchored
# E4.1                                                                                                                           Anchored/seismic components
# E4.1a                                                                                                                          Anchored/seismic components
# E4.1b                                                                                                                          Anchored/seismic components
# E4.2                                                                                                                        Unanchored/standard components
# E4.2a                                                                                                                       Unanchored/standard components
# E4.2b                                                                                                                       Unanchored/standard components
# E5.1                                                                                                            Distribution circuit with seismic/anchored
# E5.1a                                                                                                           Distribution circuit with seismic/anchored
# E5.1b                                                                                                           Distribution circuit with seismic/anchored
# E5.2                                                                                              Distribution circuit with unanchored/standard components
# E5.2a                                                                                             Distribution circuit with unanchored/standard components
# E5.2b                                                                                             Distribution circuit with unanchored/standard components
# E6.1                                                                                                            Distribution circuit with seismic/anchored
# E6.1a                                                                                                           Distribution circuit with seismic/anchored
# E6.1b                                                                                                           Distribution circuit with seismic/anchored
# E6.2                                                                                              Distribution circuit with unanchored/standard components
# E6.2a                                                                                             Distribution circuit with unanchored/standard components
# E6.2b                                                                                             Distribution circuit with unanchored/standard components
# E8.1                                                                                                  Fuel facility: Anchored components with backup power
# E8.1a                                                                                                 Fuel facility: Anchored components with backup power
# E8.1b                                                                                                 Fuel facility: Anchored components with backup power
# E8.2                                                                                                   Fuel facility: Anchored components w/o backup power
# E8.2a                                                                                                  Fuel facility: Anchored components w/o backup power
# E8.2b                                                                                                  Fuel facility: Anchored components w/o backup power
# E8.3                                                                                                Fuel facility: Unanchored components with backup power
# E8.3a                                                                                               Fuel facility: Unanchored components with backup power
# E8.3b                                                                                               Fuel facility: Unanchored components with backup power
# E8.4                                                                                                 Fuel facility: Unanchored components w/o backup power
# E8.4a                                                                                                Fuel facility: Unanchored components w/o backup power
# E8.4b                                                                                                Fuel facility: Unanchored components w/o backup power
# E8.5                                                                                              Dispatch facility: Anchored components with backup power
# E8.5a                                                                                             Dispatch facility: Anchored components with backup power
# E8.5b                                                                                             Dispatch facility: Anchored components with backup power
# E8.6                                                                                               Dispatch facility: Anchored components w/o backup power
# E8.6a                                                                                              Dispatch facility: Anchored components w/o backup power
# E8.6b                                                                                              Dispatch facility: Anchored components w/o backup power
# E8.7                                                                                            Dispatch facility: Unanchored components with backup power
# E8.7a                                                                                           Dispatch facility: Unanchored components with backup power
# E8.7b                                                                                           Dispatch facility: Unanchored components with backup power
# E8.8                                                                                             Dispatch facility: Unanchored components w/o backup power
# E8.8a                                                                                            Dispatch facility: Unanchored components w/o backup power
# E8.8b                                                                                            Dispatch facility: Unanchored components w/o backup power
# E8.9                                                                                                              Light rail DC Power substation: anchored
# E8.9a                                                                                                             Light rail DC Power substation: anchored
# E8.9b                                                                                                             Light rail DC Power substation: anchored
# E8.10                                                                                                           Light rail DC Power substation: unanchored
# E8.10a                                                                                                          Light rail DC Power substation: unanchored
# E8.10b                                                                                                          Light rail DC Power substation: unanchored
# E9.1                                                                                                                 Anchored components with backup power
# E9.1a                                                                                                                Anchored components with backup power
# E9.1b                                                                                                                Anchored components with backup power
# E9.2                                                                                                                  Anchored components w/o backup power
# E9.2a                                                                                                                 Anchored components w/o backup power
# E9.2b                                                                                                                 Anchored components w/o backup power
# E9.3                                                                                                               Unanchored components with backup power
# E9.3a                                                                                                              Unanchored components with backup power
# E9.3b                                                                                                              Unanchored components with backup power
# E9.4                                                                                                                Unanchored components w/o backup power
# E9.4a                                                                                                               Unanchored components w/o backup power
# E9.4b                                                                                                               Unanchored components w/o backup power
# E12.1                                                                                   Central offices and broadcasting stations with anchored components
# E12.1a                                                                                  Central offices and broadcasting stations with anchored components
# E12.1b                                                                                  Central offices and broadcasting stations with anchored components
# E12.2                                                                                Central offices and broadcasting stations without anchored components
# E12.2a                                                                               Central offices and broadcasting stations without anchored components
# E12.2b                                                                               Central offices and broadcasting stations without anchored components
# E13.1                                                                                                Water storage tanks On-ground concrete tank, anchored
# E13.1a                                                                                               Water storage tanks On-ground concrete tank, anchored
# E13.1b                                                                                               Water storage tanks On-ground concrete tank, anchored
# E13.2                                                                                              Water storage tanks On-ground concrete tank, unanchored
# E13.2a                                                                                             Water storage tanks On-ground concrete tank, unanchored
# E13.2b                                                                                             Water storage tanks On-ground concrete tank, unanchored
# E13.3                                                                                                   Water storage tanks On-ground steel tank, anchored
# E13.3a                                                                                                  Water storage tanks On-ground steel tank, anchored
# E13.3b                                                                                                  Water storage tanks On-ground steel tank, anchored
# E13.4                                                                                                 Water storage tanks On-ground steel tank, unanchored
# E13.4a                                                                                                Water storage tanks On-ground steel tank, unanchored
# E13.4b                                                                                                Water storage tanks On-ground steel tank, unanchored
# E13.5                                                                                                          Water storage tanks Above-ground steel tank
# E13.5a                                                                                                         Water storage tanks Above-ground steel tank
# E13.5b                                                                                                         Water storage tanks Above-ground steel tank
# E13.6                                                                                                              Water storage tanks On-ground wood tank
# E13.6a                                                                                                             Water storage tanks On-ground wood tank
# E13.6b                                                                                                             Water storage tanks On-ground wood tank
# E14.1                                                                                                                                      Small, anchored
# E14.1 a                                                                                                                                    Small, anchored
# E14.1b                                                                                                                                     Small, anchored
# E14.2                                                                                                                                    Small, unanchored
# E14.2a                                                                                                                                   Small, unanchored
# E14.2b                                                                                                                                   Small, unanchored
# E14.3                                                                                                                                     Medium, anchored
# E14.3a                                                                                                                                    Medium, anchored
# E14.3b                                                                                                                                    Medium, anchored
# E14.4                                                                                                                                   Medium, unanchored
# E14.4a                                                                                                                                  Medium, unanchored
# E14.4b                                                                                                                                  Medium, unanchored
# E14.5                                                                                                                                      Large, anchored
# E14.5a                                                                                                                                     Large, anchored
# E14.5b                                                                                                                                     Large, anchored
# E14.6                                                                                                                                    Large, unanchored
# E14.6a                                                                                                                                   Large, unanchored
# E14.6b                                                                                                                                   Large, unanchored
# E15.1                                                                                                                                             Anchored
# E15.1a                                                                                                                                            Anchored
# E15.1b                                                                                                                                            Anchored
# E16.24     PVC, continious joint type continuous (i.e., different parts of pipes are connected with each other using glue and heating), diameter 25-500 mm
# E17.1                                                                                                                        Small pumping plant, anchored
# E17.1a                                                                                                                       Small pumping plant, anchored
# E17.1b                                                                                                                       Small pumping plant, anchored
# E17.2                                                                                                                      Small pumping plant, unanchored
# E17.2a                                                                                                                     Small pumping plant, unanchored
# E17.2b                                                                                                                     Small pumping plant, unanchored
# E17.3                                                                                                                 Medium/large pumping plant, anchored
# E17.3a                                                                                                                Medium/large pumping plant, anchored
# E17.3b                                                                                                                Medium/large pumping plant, anchored
# E17.4                                                                                                               Medium/large pumping plant, unanchored
# E17.4a                                                                                                              Medium/large pumping plant, unanchored
# E17.4b                                                                                                              Medium/large pumping plant, unanchored
# E18.1                                                                                                           Small anchored wastewater treatment plants
# E18.1a                                                                                                          Small anchored wastewater treatment plants
# E18.1b                                                                                                          Small anchored wastewater treatment plants
# E18.2                                                                                                         Small unanchored wastewater treatment plants
# E18.2a                                                                                                        Small unanchored wastewater treatment plants
# E18.2b                                                                                                        Small unanchored wastewater treatment plants
# E18.3                                                                                                          Medium anchored wastewater treatment plants
# E18.3a                                                                                                         Medium anchored wastewater treatment plants
# E18.3b                                                                                                         Medium anchored wastewater treatment plants
# E18.4                                                                                                        Medium unanchored wastewater treatment plants
# E18.4a                                                                                                       Medium unanchored wastewater treatment plants
# E18.4b                                                                                                       Medium unanchored wastewater treatment plants
# E18.5                                                                                                           Large anchored wastewater treatment plants
# E18.5a                                                                                                          Large anchored wastewater treatment plants
# E18.5b                                                                                                          Large anchored wastewater treatment plants
# E18.6                                                                                                         Large unanchored wastewater treatment plants
# E18.6a                                                                                                        Large unanchored wastewater treatment plants
# E18.6b                                                                                                        Large unanchored wastewater treatment plants
# E20.1                                                                                                                                small lift - anchored
# E20.1a                                                                                                                               small lift - anchored
# E20.1b                                                                                                                               small lift - anchored
# E20.2                                                                                                                              small lift - unanchored
# E20.2a                                                                                                                             small lift - unanchored
# E20.2b                                                                                                                             small lift - unanchored
# E20.3                                                                                                                         medium/large lift - anchored
# E20.3a                                                                                                                        medium/large lift - anchored
# E20.3b                                                                                                                        medium/large lift - anchored
# E20.4                                                                                                                              medium/large unanchored
# E20.4a                                                                                                                             medium/large unanchored
# E20.4b                                                                                                                             medium/large unanchored
# E21.11                                                                                                             Reinforced concrete four-story building
# E21.11a                                                                                                            Reinforced concrete four-story building
# E21.11b                                                                                                            Reinforced concrete four-story building

# %% [markdown]
# And select a curve to use for each different subtype we are analysing.

# %%
sub_types
# Out:
# array(['Cable'], dtype=object)

# %%
selected_curves = dict(zip(sub_types,['E5.1','E5.1a','E5.1b','E5.2','E5.2a','E5.2b'])) #NOTE: these are incorrect curves for Roads. This is an example.

# %% [markdown]
# The next step is to extract the curves from the database, and prepare them for proper usage into our analysis.
#
# We start by selecting the curve IDs from the larger pandas DataFrame **vul_df**:

# %%
damage_curves = vul_df[['ID number']+list(selected_curves.values())]
damage_curves = damage_curves.iloc[4:125,:]

# %% [markdown]
# Then for convenience, we rename the index name to the hazard intensity we are considering.

# %%
damage_curves.set_index('ID number',inplace=True)
damage_curves.index = damage_curves.index.rename('PGA')

# %% [markdown]
# And make sure that our damage values are in floating numbers.

# %%
damage_curves = damage_curves.astype(np.float32)

# %% [markdown]
# And ensure that the columns of the curves link back to the different asset types we are considering:

# %%
damage_curves.columns = sub_types

# %% [markdown]
# There could be some **NaN** values at the tail of some of the curves. To make sure the code works, we fill up the **NaN** values with the last value of each of the curves.

# %%
damage_curves = damage_curves.fillna(method='ffill')

# %% [markdown]
# Finally, make sure we set the index of the damage curves (the PGA levels) in the same metric as the hazard data.

# %%
damage_curves.index = damage_curves.index*980

# %% [markdown]
# ### Ancilliary data for processing

# %%
world = gpd.read_file("https://github.com/nvkelso/natural-earth-vector/raw/master/10m_cultural/ne_10m_admin_0_countries.shp")
world_plot = world.to_crs(3857)

# %%
admin1 = gpd.read_file("https://github.com/nvkelso/natural-earth-vector/raw/master/10m_cultural/ne_10m_admin_1_states_provinces.shp")

# %% [markdown]
# ## 3. Preparing the Data

# %% [markdown]
# Clip the hazard data to the country of interest.

# %%
country_bounds = world.loc[world.ADM0_ISO == country_iso3].bounds
country_geom = world.loc[world.ADM0_ISO == country_iso3].geometry

# %%
country_gdf = gpd.GeoDataFrame(geometry=country_geom, crs="EPSG:4326")
clipped_country = gpd.clip(country_gdf, city_path)

# %%
hazard_country = hazard_map.rio.clip_box(minx=country_bounds.minx.values[0],
                     miny=country_bounds.miny.values[0],
                     maxx=country_bounds.maxx.values[0],
                     maxy=country_bounds.maxy.values[0]
                    )

# %%
hazard_city = hazard_country.rio.clip(city_path.geometry, city_path.crs)

# %%
print(hazard_city.data_vars)
# Out:
# Data variables:
#     band_data  (band, y, x) float32 25kB nan nan nan nan nan ... nan nan nan nan

# %%
fig, ax = plt.subplots(figsize=(10, 10))
hazard_country.band_data.plot(ax=ax, cmap="inferno", vmin=0)
country_geom.plot(ax=ax, edgecolor='blue', facecolor='none', lw=2, linestyle='--')
plt.title("Hazard Country Raster (Masked by AOI)")
plt.axis("off")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
hazard_country.band_data.plot(ax=ax, cmap="inferno", vmin=0)
city_path.plot(ax=ax, edgecolor='blue', facecolor='none', lw=2, linestyle='--')
plt.title("Hazard City Raster (Masked by AOI)")
plt.axis("off")
plt.show()

# %% [markdown]
# ## 4. Performing an Exposure Assessment
# We will use the DamageScanner approach. This is a fully optimised damage calculation method, that can capture a wide range of inputs to perform a damage assessment. It also allows to only assess the potential exposure.

# %%
exposure_results = DamageScanner(hazard_city, clipped_features, damage_curves, maxdam).exposure()
# Out:
# Traceback (most recent call last):                        | 0/1 [00:00<?, ?it/s]
#   File "/Users/ipshitakarmakar/mambaforge/envs/infra-risk/lib/python3.12/site-packages/damagescanner/vector.py", line 360, in _overlay_raster_vector
#     values_and_coverage_per_area_and_line_object = exact_extract(
#                                                    ^^^^^^^^^^^^^^
#   File "/Users/ipshitakarmakar/mambaforge/envs/infra-risk/lib/python3.12/site-packages/exactextract/exact_extract.py", line 492, in exact_extract
#     processor.process()
# RuntimeError: Failed to parse geometry.
# Overlay raster with vector: 100%|█████████████████| 1/1 [00:00<00:00, 41.90it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 exposure_results = DamageScanner(hazard_city, clipped_features, damage_curves, maxdam).exposure()
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/damagescanner/core.py:108, in DamageScanner.exposure(self, disable_progress, **kwargs)
#     105 else:
#     106     self.asset_type = "landuse"
# --> 108 exposed_assets = VectorExposure(
#     109     hazard_file=self.hazard_data,
#     110     feature_file=self.feature_data,
#     111     asset_type=self.asset_type,
#     112     disable_progress=disable_progress,
#     113 )[0]
#     115 return exposed_assets
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/damagescanner/vector.py:593, in VectorExposure(hazard_file, feature_file, asset_type, object_col, disable_progress)
#     591 # Run exposure overlay
#     592 if isinstance(hazard, (rasterio.io.DatasetReader, xr.Dataset, xr.DataArray)):
# --> 593     features = _overlay_raster_vector(hazard, features, hazard_crs, disable_progress=disable_progress)
#     594 elif isinstance(hazard, (gpd.GeoDataFrame, pd.DataFrame)):
#     595     features = _overlay_vector_vector(hazard, features) ## NOT WORKING YET
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/damagescanner/vector.py:379, in _overlay_raster_vector(hazard, features, hazard_crs, hazard_col, nodata, gridded, disable_progress)
#     376         if error_to_ignore not in get_error:
#     377             traceback.print_exc()
# --> 379 df = pd.concat(collect_overlay).sort_index()
#     381 # remove duplicates
#     382 df_no_duplicates = _remove_duplicates(df)
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
#hazard_country,features for the country instead

# %% [markdown]
# ## 5. Performing a Vulnerability Assessment
# In some cases, the cost information is unavailable, or one wants to explore only the exposure and vulnerability. To do so, we simply run the DamageScanner, by setting the maximum costs to 1.

# %%
vulnerability_maxdam = maxdam.copy()
vulnerability_maxdam.loc[:,'damage'] = maxdam['damage']/maxdam['damage']

# %%
# %%time
vulnerability_results = DamageScanner(hazard_city, clipped_features, damage_curves, vulnerability_maxdam).calculate()
# Out:
# Traceback (most recent call last):                        | 0/1 [00:00<?, ?it/s]
#   File "/Users/ipshitakarmakar/mambaforge/envs/infra-risk/lib/python3.12/site-packages/damagescanner/vector.py", line 360, in _overlay_raster_vector
#     values_and_coverage_per_area_and_line_object = exact_extract(
#                                                    ^^^^^^^^^^^^^^
#   File "/Users/ipshitakarmakar/mambaforge/envs/infra-risk/lib/python3.12/site-packages/exactextract/exact_extract.py", line 492, in exact_extract
#     processor.process()
# RuntimeError: Failed to parse geometry.
# Overlay raster with vector: 100%|█████████████████| 1/1 [00:00<00:00, 51.25it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/damagescanner/core.py:140, in DamageScanner.calculate(self, disable_progress, save_output, **kwargs)
#     137 else:
#     138     self.asset_type = None
# --> 140 return VectorScanner(
#     141     hazard_file=self.hazard_data,
#     142     feature_file=self.feature_data,
#     143     curve_path=self.curves,
#     144     maxdam_path=self.maxdam,
#     145     asset_type=self.asset_type,  #'landuse',
#     146     multi_curves=kwargs.get("multi_curves", None),
#     147     sub_types=kwargs.get("subtypes", None),
#     148     disable_progress=disable_progress,
#     149     save=save_output,
#     150 )
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/damagescanner/vector.py:655, in VectorScanner(hazard_file, feature_file, curve_path, maxdam_path, asset_type, multi_curves, object_col, disable_progress, save, **kwargs)
#     611 """
#     612 Vector based implementation of a direct damage assessment
#     613
#    (...)    651
#     652 """
#     654 # Load hazard and exposure data, and perform the overlay
# --> 655 features, object_col, hazard_crs, cell_area_m2 = VectorExposure(
#     656     hazard_file, feature_file, asset_type, object_col, disable_progress
#     657 )
#     659 if len(features) == 0:
#     660     return features
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/damagescanner/vector.py:593, in VectorExposure(hazard_file, feature_file, asset_type, object_col, disable_progress)
#     591 # Run exposure overlay
#     592 if isinstance(hazard, (rasterio.io.DatasetReader, xr.Dataset, xr.DataArray)):
# --> 593     features = _overlay_raster_vector(hazard, features, hazard_crs, disable_progress=disable_progress)
#     594 elif isinstance(hazard, (gpd.GeoDataFrame, pd.DataFrame)):
#     595     features = _overlay_vector_vector(hazard, features) ## NOT WORKING YET
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/damagescanner/vector.py:379, in _overlay_raster_vector(hazard, features, hazard_crs, hazard_col, nodata, gridded, disable_progress)
#     376         if error_to_ignore not in get_error:
#     377             traceback.print_exc()
# --> 379 df = pd.concat(collect_overlay).sort_index()
#     381 # remove duplicates
#     382 df_no_duplicates = _remove_duplicates(df)
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %% [markdown]
# Important for the earthquake assessment, is the fact that liquefaction can be an important driver of the damages, especially for road and railways. As such, we also overlay our results with a [global liquefaction map](https://zenodo.org/records/2583746), to be able to correct the results.

# %%
liqeufaction_map = xr.open_dataset("https://zenodo.org/records/2583746/files/liquefaction_v1_deg.tif", engine="rasterio")

# %%
liqeufaction_country = liqeufaction_map.rio.clip_box(minx=country_bounds.minx.values[0],
                     miny=country_bounds.miny.values[0],
                     maxx=country_bounds.maxx.values[0],
                     maxy=country_bounds.maxy.values[0]
                    ).copy(deep=True)

# %%
liqeufaction_city = liqeufaction_country.rio.clip(city_path.geometry, city_path.crs)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
liqeufaction_city.band_data.plot(ax=ax, cmap="inferno", vmin=0)
city_path.plot(ax=ax, edgecolor='blue', facecolor='none', lw=2, linestyle='--')
plt.title("Hazard City Raster")
plt.axis("off")
plt.show()

# %%
liquefaction_results = DamageScanner(liqeufaction_city, clipped_features, damage_curves, maxdam).exposure()
# Out:
# Traceback (most recent call last):                        | 0/1 [00:00<?, ?it/s]
#   File "/Users/ipshitakarmakar/mambaforge/envs/infra-risk/lib/python3.12/site-packages/damagescanner/vector.py", line 360, in _overlay_raster_vector
#     values_and_coverage_per_area_and_line_object = exact_extract(
#                                                    ^^^^^^^^^^^^^^
#   File "/Users/ipshitakarmakar/mambaforge/envs/infra-risk/lib/python3.12/site-packages/exactextract/exact_extract.py", line 492, in exact_extract
#     processor.process()
# RuntimeError: Failed to parse geometry.
# Overlay raster with vector: 100%|█████████████████| 1/1 [00:00<00:00, 44.06it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 liquefaction_results = DamageScanner(liqeufaction_city, clipped_features, damage_curves, maxdam).exposure()
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/damagescanner/core.py:108, in DamageScanner.exposure(self, disable_progress, **kwargs)
#     105 else:
#     106     self.asset_type = "landuse"
# --> 108 exposed_assets = VectorExposure(
#     109     hazard_file=self.hazard_data,
#     110     feature_file=self.feature_data,
#     111     asset_type=self.asset_type,
#     112     disable_progress=disable_progress,
#     113 )[0]
#     115 return exposed_assets
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/damagescanner/vector.py:593, in VectorExposure(hazard_file, feature_file, asset_type, object_col, disable_progress)
#     591 # Run exposure overlay
#     592 if isinstance(hazard, (rasterio.io.DatasetReader, xr.Dataset, xr.DataArray)):
# --> 593     features = _overlay_raster_vector(hazard, features, hazard_crs, disable_progress=disable_progress)
#     594 elif isinstance(hazard, (gpd.GeoDataFrame, pd.DataFrame)):
#     595     features = _overlay_vector_vector(hazard, features) ## NOT WORKING YET
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/damagescanner/vector.py:379, in _overlay_raster_vector(hazard, features, hazard_crs, hazard_col, nodata, gridded, disable_progress)
#     376         if error_to_ignore not in get_error:
#     377             traceback.print_exc()
# --> 379 df = pd.concat(collect_overlay).sort_index()
#     381 # remove duplicates
#     382 df_no_duplicates = _remove_duplicates(df)
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
print(liquefaction_results)
# Out:
#             osm_id                                           geometry lanes  \
# 84809    601543676  LINESTRING (15.73875 -12.85402, 15.74012 -12.8...  None
# 84922    601552381  LINESTRING (15.74202 -12.85176, 15.7421 -12.85...  None
# 89991    603206182  LINESTRING (15.74536 -12.8452, 15.74536 -12.84...  None
# 89954    603205908  LINESTRING (15.75085 -12.8448, 15.75072 -12.84...  None
# 93297    605159167  LINESTRING (15.74031 -12.84698, 15.74052 -12.8...  None
# ...            ...                                                ...   ...
# 218252  1217974878  LINESTRING (15.78529 -12.55931, 15.78528 -12.5...  None
# 12228    203452972  LINESTRING (15.80106 -12.5564, 15.79774 -12.55...  None
# 178105   710790093  LINESTRING (15.78389 -12.55691, 15.78595 -12.5...  None
# 178106   710790094  LINESTRING (15.78549 -12.55931, 15.78477 -12.5...  None
# 187646   732255318  LINESTRING (15.75639 -12.56375, 15.75645 -12.5...  None
#
#         surface   object_type  \
# 84809      None   residential
# 84922      None   residential
# 89991      None   residential
# 89954      None   residential
# 93297      None  unclassified
# ...         ...           ...
# 218252  unpaved  unclassified
# 12228   unpaved      tertiary
# 178105     None         track
# 178106  unpaved  unclassified
# 187646     None   residential
#
#                                                  coverage  \
# 84809             [80.39100291391435, 491.86174394360506]
# 84922                                 [340.2930498565694]
# 89991              [624.3990710442235, 720.9630117525397]
# 89954               [330.1702427391573, 78.7025304265303]
# 93297                                 [391.8572836340069]
# ...                                                   ...
# 218252                               [505.43495585890696]
# 12228   [143.00981735990385, 1146.8408754504014, 1148....
# 178105                                [275.3527072474163]
# 178106            [19.583611088891768, 518.1583846085646]
# 187646             [520.0484286366708, 488.8223797247153]
#
#                                      values
# 84809                            [1.0, 1.0]
# 84922                                 [1.0]
# 89991                            [3.0, 1.0]
# 89954                            [3.0, 1.0]
# 93297                                 [3.0]
# ...                                     ...
# 218252                                [3.0]
# 12228   [1.0, 1.0, 1.0, 3.0, 3.0, 3.0, 1.0]
# 178105                                [3.0]
# 178106                           [3.0, 3.0]
# 187646                           [1.0, 3.0]
#
# [7376 rows x 7 columns]

# %% [markdown]
# Based on the Supplementary Table S6 as provided by [Koks et al (2019)](https://www.nature.com/articles/s41467-019-10442-3), we identify which combinations of liquefaction and earthquake intensity should result in damages.

# %%
damage_dict = {
    (1, 1): 0, (1, 2): 0, (1, 3): 0, (1, 4): 0, (1, 5): 0,
    (2, 1): 1, (2, 2): 0, (2, 3): 0, (2, 4): 0, (2, 5): 0,
    (3, 1): 1, (3, 2): 1, (3, 3): 0, (3, 4): 0, (3, 5): 0,
    (4, 1): 1, (4, 2): 1, (4, 3): 1, (4, 4): 0, (4, 5): 0,
    (5, 1): 1, (5, 2): 1, (5, 3): 1, (5, 4): 1, (5, 5): 0,
    (6, 1): 0, (6, 2): 0, (6, 3): 0, (6, 4): 0, (6, 5): 0,
}

# %% [markdown]
# To make things efficient, below we have written a small function to identify those assets that may or may not have damage. If they fall within a damage category, they receive a '1', if they do not fall within a damage category, they receive a '0'.

# %%
def get_damage_bool(feature,liquefaction_results,damage_dict):

    liq_value = mode(liquefaction_results.loc[feature.name]['values'])

    if int(liq_value) == 0:
        return 0
    
    eq_value = mode(np.digitize(feature['values'], bins=[0, 0.092*980, 0.18*980, 0.34*980, 0.65*980, float('inf')]))

    return damage_dict[(eq_value,liq_value)]

# %%
def get_damage_bool(feature, liquefaction_results, damage_dict):
    liq_value = mode(liquefaction_results.loc[feature.name]['values'])
    eq_value = mode(np.digitize(feature['values'], bins=[0, 0.092*980, 0.18*980, 0.34*980, 0.65*980, float('inf')]))
    
    result = damage_dict.get((eq_value, liq_value), 0)
    
    # Print the result type
    print(f"Feature: {feature.name}, Result Type: {type(result)}, Result: {result}")
    
    return result

# %%
tqdm.pandas(desc='liquefaction correction boolean')
vulnerability_results['liquefaction_corr'] = vulnerability_results.progress_apply(
    lambda feature: get_damage_bool(feature, liquefaction_results, damage_dict), axis=1, result_type='reduce'
)
vulnerability_results['vuln_corrected'] = vulnerability_results['damage']*vulnerability_results['liquefaction_corr']
# Out:
# liquefaction correction boolean: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'damage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 5
#       1 tqdm.pandas(desc='liquefaction correction boolean')
#       2 vulnerability_results['liquefaction_corr'] = vulnerability_results.progress_apply(
#       3     lambda feature: get_damage_bool(feature, liquefaction_results, damage_dict), axis=1, result_type='reduce'
#       4 )
# ----> 5 vulnerability_results['vuln_corrected'] = vulnerability_results['damage']*vulnerability_results['liquefaction_corr']
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/geopandas/geodataframe.py:1750, in GeoDataFrame.__getitem__(self, key)
#    1744 def __getitem__(self, key):
#    1745     """
#    1746     If the result is a column containing only 'geometry', return a
#    1747     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1748     return a GeoDataFrame.
#    1749     """
# -> 1750     result = super().__getitem__(key)
#    1751     # Custom logic to avoid waiting for pandas GH51895
#    1752     # result is not geometry dtype for multi-indexes
#    1753     if (
#    1754         pd.api.types.is_scalar(key)
#    1755         and key == ""
#    (...)   1758         and not is_geometry_type(result)
#    1759     ):
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'damage'

# %% [markdown]
# ## 6. Performing the Damage Assessment
# In case we do have cost values, we can fully assess the damages.

# %%
# %%time
damage_results = DamageScanner(hazard_country, features, damage_curves, maxdam).calculate()
# Out:
# Overlay raster with vector: 100%|█████████████| 700/700 [06:23<00:00,  1.82it/s]
# convert coverage to meters: 100%|██████████████| 47/47 [00:00<00:00, 379.18it/s]
# Calculating damage: 100%|████████████████████| 47/47 [00:00<00:00, 22726.80it/s]
# CPU times: user 6min 24s, sys: 3.08 s, total: 6min 27s
# Wall time: 6min 30s

# %%
fig, ax = plt.subplots(figsize=(10, 10))
damage_results.plot(ax=ax, edgecolor='red', facecolor='none', lw=2, linestyle='-')
country_geom.plot(ax=ax, edgecolor='blue', facecolor='none', lw=2, linestyle='--')
plt.title("Hazard City Raster")
plt.axis("off")
plt.show()

# %%
# %%time
damage_results_city = DamageScanner(hazard_city, clipped_features, damage_curves, maxdam).calculate()
# Out:
# Overlay raster with vector: 100%|█████████████████| 1/1 [00:09<00:00,  9.97s/it]
# convert coverage to meters: 1it [00:00, 2939.25it/s]
# CPU times: user 10.1 s, sys: 101 ms, total: 10.2 s
# Wall time: 10.2 s

# %%
print(damage_results_city)
# Out:
# Empty GeoDataFrame
# Columns: [osm_id, geometry, lanes, surface, object_type, coverage, values]
# Index: []

# %% [markdown]
# And again, we correct for the liquefaction

# %%
tqdm.pandas(desc='liquefaction correction boolean')
damage_results_city['liquefaction_corr'] = damage_results_city.progress_apply(lambda feature: get_damage_bool(feature,liquefaction_results,damage_dict),axis=1)
damage_results_city['damage_corrected'] = damage_results_city['damage']*damage_results_city['liquefaction_corr']
# Out:
# liquefaction correction boolean: 1it [00:00, 221.14it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/tb/lt6mv9zn47973s97jtlwv_b40000gn/T/ipykernel_30868/1306234453.py in ?()
#       1 tqdm.pandas(desc='liquefaction correction boolean')
# ----> 2 damage_results_city['liquefaction_corr'] = damage_results_city.progress_apply(lambda feature: get_damage_bool(feature,liquefaction_results,damage_dict),axis=1)
#       3 damage_results_city['damage_corrected'] = damage_results_city['damage']*damage_results_city['liquefaction_corr']
#
# ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/geopandas/geodataframe.py in ?(self, key, value)
#    1815                 warnings.warn(
#    1816                     "Geometry column does not contain geometry.",
#    1817                     stacklevel=2,
#    1818                 )
# -> 1819         super().__setitem__(key, value)
#
# ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#    4304             and not self.columns.is_unique
#
# ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4455
#    4456             return self.isetitem(locs, value)
#    4457
#    4458         if len(value.columns) > 1:
# -> 4459             raise ValueError(
#    4460                 "Cannot set a DataFrame with multiple columns to the single "
#    4461                 f"column {key}"
#    4462             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column liquefaction_corr

# %% [markdown]
# ## 7. Save the Results
# For further analysis, we can save the results in their full detail, or save summary estimates per subnational unit. We show how to do this using the damage results.

# %%
hazard = 'earthquake'
return_period = '1_475'
damage_results.to_file(f'Road_Damage_{country_full_name}_{hazard}_{return_period}.gpkg')

# %%
admin1_country = admin1.loc[admin1.sov_a3 == country_iso3]

# %%
damage_results = damage_results.sjoin(admin1_country[['adm1_code','name','geometry']])

# %%
admin1_damage = admin1_country.merge(damage_results[['name','damage']].groupby('name').sum(),
                                     left_on='name',
                                     right_on='name',
                                     how='outer')[['name','adm1_code','geometry','damage']]

# %%
admin1_damage.to_file(f'Admin1_Road_Damage_{country_full_name}_{hazard}_{return_period}.gpkg')

# %% [markdown]
# ## 8. Visualizing the Results
# The results of the damage assessment can be visualized using charts and maps. This will provide a clear representation of which infrastructure is most affected by the hazard and the expected damage levels.

# %% [markdown]
# Find the locations of the twenty most damaged roads.

# %%
fig, ax = plt.subplots(1,1,figsize=(10, 5))

damage_results.to_crs(3857).head(20).plot(ax=ax,color='Red')
features.to_crs(3857).plot(ax=ax,facecolor="none",edgecolor='grey',alpha=0.5,zorder=2,lw=0.1)
world_plot.loc[world.SOV_A3 == country_iso3].plot(ax=ax,facecolor="none",edgecolor='black')
cx.add_basemap(ax, source=cx.providers.CartoDB.Positron,alpha=0.5)
ax.set_axis_off()

# %%
fig, ax = plt.subplots(1,1,figsize=(10, 5))
damage_results.to_crs(3857).plot(ax=ax, color='Red')
clipped_features.to_crs(3857).plot(ax=ax, facecolor="none", edgecolor='grey', alpha=0.5, zorder=2, lw=0.1)
city_path.to_crs(3857).plot(ax=ax, facecolor="none", edgecolor='black', linewidth=1.5)
cx.add_basemap(ax, source=cx.providers.CartoDB.Positron, alpha=0.5)
ax.set_axis_off()
minx, miny, maxx, maxy = city_path.to_crs(3857).total_bounds
ax.set_xlim(minx, maxx)
ax.set_ylim(miny, maxy)

plt.show()

# %% [markdown]
# And create a distribution of the damages.

# %%
fig, ax = plt.subplots(1,1,figsize=(7, 3))

sns.histplot(data=damage_results,x='damage',ax=ax)
# Out:
# <Axes: xlabel='damage', ylabel='Count'>

# %% [markdown]
# Plot all damages

# %%
fig, ax = plt.subplots(1,1,figsize=(10, 5))

damage_results.to_crs(3857).plot(ax=ax,column='damage_corrected',cmap='Reds',legend=True,
                   legend_kwds={'shrink': 0.5,'label':'Absolute Damage'},zorder=5)
features.to_crs(3857).plot(ax=ax,facecolor="none",edgecolor='grey',alpha=0.5,zorder=2,lw=0.1)
world_plot.loc[world.SOV_A3 == country_iso3].plot(ax=ax,facecolor="none",edgecolor='black')
cx.add_basemap(ax, source=cx.providers.CartoDB.Positron,alpha=0.5)
ax.set_axis_off()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'damage_corrected'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 3
#       1 fig, ax = plt.subplots(1,1,figsize=(10, 5))
# ----> 3 damage_results.to_crs(3857).plot(ax=ax,column='damage_corrected',cmap='Reds',legend=True,
#       4                    legend_kwds={'shrink': 0.5,'label':'Absolute Damage'},zorder=5)
#       5 features.to_crs(3857).plot(ax=ax,facecolor="none",edgecolor='grey',alpha=0.5,zorder=2,lw=0.1)
#       6 world_plot.loc[world.SOV_A3 == country_iso3].plot(ax=ax,facecolor="none",edgecolor='black')
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/geopandas/plotting.py:968, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     966 kind = kwargs.pop("kind", "geo")
#     967 if kind == "geo":
# --> 968     return plot_dataframe(data, *args, **kwargs)
#     969 if kind in self._pandas_kinds:
#     970     # Access pandas plots
#     971     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/geopandas/plotting.py:715, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, autolim, **style_kwds)
#     713             values = values.reindex(df.index)
#     714 else:
# --> 715     values = df[column]
#     717 if isinstance(values.dtype, CategoricalDtype):
#     718     if categories is not None:
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/geopandas/geodataframe.py:1750, in GeoDataFrame.__getitem__(self, key)
#    1744 def __getitem__(self, key):
#    1745     """
#    1746     If the result is a column containing only 'geometry', return a
#    1747     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1748     return a GeoDataFrame.
#    1749     """
# -> 1750     result = super().__getitem__(key)
#    1751     # Custom logic to avoid waiting for pandas GH51895
#    1752     # result is not geometry dtype for multi-indexes
#    1753     if (
#    1754         pd.api.types.is_scalar(key)
#    1755         and key == ""
#    (...)   1758         and not is_geometry_type(result)
#    1759     ):
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/mambaforge/envs/infra-risk/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'damage_corrected'
